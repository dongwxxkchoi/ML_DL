# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
list1_1 = [6.6, 8.4, 6.1, 6.0, 9.2, 2.9, 5.4, 6.0, 6.2, 6.9, 3.1, 10.2, 1.0]
list1_2 = [7.9, 5.1, 6.3, 6.2, 5.7, 3.1, 3.8, 6.5, 8.7, 8.7, 5.5, 9.8, 0.7]
list1_3 = [5.7, 5.7, 6.9, 6.2, 6.6, 4.4, 4.4, 6.7, 8.0, 7.2, 4.8, 10.5, 0.9]
list1_4 = [5.2, 7.9, 7.5, 5.2, 6.2, 2.9, 4.2, 5.5, 8.1, 8.0, 6.6, 10.2, 0.5]
list1_5 = [7.1, 6.4, 7.8, 8.2, 5.6, 4.3, 4.8, 4.7, 7.9, 6.3, 5.4, 8.6, 0.9]
list1_6 = [6.9, 7.1, 6.5, 6.4, 5.8, 3.8, 3.8, 7.2, 4.3, 8.5, 7.7, 8.9, 1.1]
list1_7 = [5.6, 5.9, 7.4, 4.4, 7.2, 3.9, 3.8, 6.6, 6.3, 7.9, 7.1, 11.3, 0.6]
list1_8 = [6.4, 6.2, 5.6, 4.0, 6.8, 5.0, 3.5, 5.0, 7.2, 9.3, 8.5, 10.1, 0.4]

list2_1 = [6.4, 8.7, 6.7, 6.0, 8.6, 2.7, 6.4, 4.3, 5.9, 6.1, 5.5, 8.1, 2.6]
list2_2 = [7.5, 6.2, 6.0, 5.8, 4.3, 2.3, 7.9, 6.2, 6.0, 8.9, 6.3, 8.1, 2.5]
list2_3 = [5.1, 5.1, 6.5, 7.8, 4.4, 4.1, 7.1, 8.2, 5.8, 7.4, 7.1, 7.5, 1.9]
list2_4 = [5.0, 8.9, 6.4, 6.3, 6.2, 3.0, 5.5, 5.7, 6.0, 7.2, 6.8, 9.5, 1.5]
list2_5 = [6.4, 6.2, 6.0, 7.3, 4.3, 2.7, 8.4, 5.3, 7.5, 7.5, 6.0, 7.9, 2.5]
list2_6 = [6.5, 7.3, 4.3, 5.2, 7.7, 3.5, 7.4, 6.3, 4.8, 7.7, 6.5, 8.4, 2.4]
list2_7 = [4.4, 8.2, 5.8, 3.8, 5.8, 4.0, 5.4, 6.9, 5.9, 7.4, 8.6, 9.0, 2.8]
list2_8 = [8.3, 5.3, 6.0, 5.1, 4.8, 2.9, 6.9, 8.7, 4.9, 9.1, 6.9, 8.2, 0.9]

list_list1 = []
list_list1.append(list1_1)
list_list1.append(list1_2)
list_list1.append(list1_3)
list_list1.append(list1_4)
list_list1.append(list1_5)
list_list1.append(list1_6)
list_list1.append(list1_7)
list_list1.append(list1_8)

list_list2 = []
list_list2.append(list2_1)
list_list2.append(list2_2)
list_list2.append(list2_3)
list_list2.append(list2_4)
list_list2.append(list2_5)
list_list2.append(list2_6)
list_list2.append(list2_7)
list_list2.append(list2_8)

# %%
n_list1 = [[],[],[],[],[],[],[],[]]
for index, d in enumerate(list_list1):
    temp = []
    for i, v in enumerate(d):
        temp.append([i, v])
    n_list1[index] = temp
    n_list1[index].sort(key = lambda x: x[1])

for d in n_list1:
    print(d)
    
for d in n_list1:
    for v in d:
        plt.scatter(v[0], v[1])
plt.show()

#plt.scatter(i, v)
#plt.show()
# Out:
# [[12, 1.0], [5, 2.9], [10, 3.1], [6, 5.4], [3, 6.0], [7, 6.0], [2, 6.1], [8, 6.2], [0, 6.6], [9, 6.9], [1, 8.4], [4, 9.2], [11, 10.2]]
# [[12, 0.7], [5, 3.1], [6, 3.8], [1, 5.1], [10, 5.5], [4, 5.7], [3, 6.2], [2, 6.3], [7, 6.5], [0, 7.9], [8, 8.7], [9, 8.7], [11, 9.8]]
# [[12, 0.9], [5, 4.4], [6, 4.4], [10, 4.8], [0, 5.7], [1, 5.7], [3, 6.2], [4, 6.6], [7, 6.7], [2, 6.9], [9, 7.2], [8, 8.0], [11, 10.5]]
# [[12, 0.5], [5, 2.9], [6, 4.2], [0, 5.2], [3, 5.2], [7, 5.5], [4, 6.2], [10, 6.6], [2, 7.5], [1, 7.9], [9, 8.0], [8, 8.1], [11, 10.2]]
# [[12, 0.9], [5, 4.3], [7, 4.7], [6, 4.8], [10, 5.4], [4, 5.6], [9, 6.3], [1, 6.4], [0, 7.1], [2, 7.8], [8, 7.9], [3, 8.2], [11, 8.6]]
# [[12, 1.1], [5, 3.8], [6, 3.8], [8, 4.3], [4, 5.8], [3, 6.4], [2, 6.5], [0, 6.9], [1, 7.1], [7, 7.2], [10, 7.7], [9, 8.5], [11, 8.9]]
# [[12, 0.6], [6, 3.8], [5, 3.9], [3, 4.4], [0, 5.6], [1, 5.9], [8, 6.3], [7, 6.6], [10, 7.1], [4, 7.2], [2, 7.4], [9, 7.9], [11, 11.3]]
# ...

# %%
n_list2 = [[],[],[],[],[],[],[],[]]
for index, d in enumerate(list_list2):
    temp = []
    for i, v in enumerate(d):
        temp.append([i, v])
    n_list2[index] = temp
    n_list2[index].sort(key = lambda x: x[1])

for d in n_list2:
    print(d)
    
for d in n_list2:
    for v in d:
        plt.scatter(v[0], v[1])
plt.show()

#plt.scatter(i, v)
#plt.show()
# Out:
# [[12, 2.6], [5, 2.7], [7, 4.3], [10, 5.5], [8, 5.9], [3, 6.0], [9, 6.1], [0, 6.4], [6, 6.4], [2, 6.7], [11, 8.1], [4, 8.6], [1, 8.7]]
# [[5, 2.3], [12, 2.5], [4, 4.3], [3, 5.8], [2, 6.0], [8, 6.0], [1, 6.2], [7, 6.2], [10, 6.3], [0, 7.5], [6, 7.9], [11, 8.1], [9, 8.9]]
# [[12, 1.9], [5, 4.1], [4, 4.4], [0, 5.1], [1, 5.1], [8, 5.8], [2, 6.5], [6, 7.1], [10, 7.1], [9, 7.4], [11, 7.5], [3, 7.8], [7, 8.2]]
# [[12, 1.5], [5, 3.0], [0, 5.0], [6, 5.5], [7, 5.7], [8, 6.0], [4, 6.2], [3, 6.3], [2, 6.4], [10, 6.8], [9, 7.2], [1, 8.9], [11, 9.5]]
# [[12, 2.5], [5, 2.7], [4, 4.3], [7, 5.3], [2, 6.0], [10, 6.0], [1, 6.2], [0, 6.4], [3, 7.3], [8, 7.5], [9, 7.5], [11, 7.9], [6, 8.4]]
# [[12, 2.4], [5, 3.5], [2, 4.3], [8, 4.8], [3, 5.2], [7, 6.3], [0, 6.5], [10, 6.5], [1, 7.3], [6, 7.4], [4, 7.7], [9, 7.7], [11, 8.4]]
# [[12, 2.8], [3, 3.8], [5, 4.0], [0, 4.4], [6, 5.4], [2, 5.8], [4, 5.8], [8, 5.9], [7, 6.9], [9, 7.4], [1, 8.2], [10, 8.6], [11, 9.0]]
# ...
